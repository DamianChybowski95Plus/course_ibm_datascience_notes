# %%
# potential code before try catch

try:
    # code to try to execute
except ZeroDivisionError:
    # code to execute if there is a ZeroDivisionError
except NameError:
    # code to execute if there is a NameError
except Exception:
    # code to execute if there is any exception
else:
    # code to execute if there is no exception / success
finally:
    # code to execute

# %%
a = 1

try:
    b = int(input("Please enter a number to divide a"))
    a = a/b
except ZeroDivisionError:
    print("The number you provided cant divide 1 because it is 0")
except ValueError:
    print("You did not provide a number")
except:
    print("Something went wrong")
else:
    print("success a=",a)
finally:
    print("Processing Complete")

# %%
def save_division(dzielna, dzielnik):
    try:
        result = dzielna / dzielnik
        return result
    except ZeroDivisionError:
        print(f"Error {ZeroDivisionError}")
        return none

save_division(10,0) # Kompilator i tak opisuje błędy; więc to bardziej do stron internetowych i logowania błędów użytkowników
# Out:
# Error <class 'ZeroDivisionError'>
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 3, in save_division(dzielna, dzielnik)
#       2 try:
# ----> 3     result = dzielna / dzielnik
#       4     return result
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       6         print(f"Error {ZeroDivisionError}")
#       7         return none
# ----> 9 save_division(10,0)
#
# Cell In[6], line 7, in save_division(dzielna, dzielnik)
#       5 except ZeroDivisionError:
#       6     print(f"Error {ZeroDivisionError}")
# ----> 7     return none
#
# NameError: name 'none' is not defined

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/" target="_blank">Joseph Santarcangelo</a>

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2023-08-0 | 2.1   | Akansha Yadav | Added optional practice section |
# | 2020-09-02  | 2.0  | Simran | Template updates to the file|
# |   |   |   |   |
#
#
#
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
