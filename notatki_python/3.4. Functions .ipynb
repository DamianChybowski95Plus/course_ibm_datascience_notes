# %%
def printAll(*args):
    print(f"''' Drukowanie dowolnej ilości przekazanych argumentów, które są konstruowane do tupla po stronie funkcji'''") 
    print(f"Liczba argumentów: {len(args)}, Typ argumemntów: {type(args)}") 
    for argument in args:
        print(argument, end=", ")
    print(end="\n\n")
    
printAll('Sidecar','Long Island','Mudslide','Carriage')


def printDictionary(**args): 
    print(f"'''Drukuje słownik o dowolnej długości który będzie skonstruowany po stronie funkcji przez pary kluczy=wartości przekazanych do funkcji jako argument'''")
    print(f"Liczba argumentów: {len(args.keys())}, Typ argumemntów: {type(args)}")
    for key in args:
        print(key + " : " + args[key])

printDictionary(Country='Canada',Province='Ontario',City='Toronto') # taki zapis oznacza przekazanie słownika o dowolnej długości;
# printDictionary({"Country" : 'Canada',"Province" : 'Ontario',"City" : 'Toronto'}) # taki zapis nie jest kompatybilny bo funkcja przyjmuje słownik zero-pozycyjny, który jest dowolnej długości, ale nie będzie skonstruowany po stronie funkcji

d = {
    "a" : 1,
    "b" : 2
}

d = { *d }

# printDictionary(**d)
# Out:
# ''' Drukowanie dowolnej ilości przekazanych argumentów, które są konstruowane do tupla po stronie funkcji'''
# Liczba argumentów: 4, Typ argumemntów: <class 'tuple'>
# Sidecar, Long Island, Mudslide, Carriage,
#
# '''Drukuje słownik o dowolnej długości który będzie skonstruowany po stronie funkcji przez pary kluczy=wartości przekazanych do funkcji jako argument'''
# Liczba argumentów: 3, Typ argumemntów: <class 'dict'>
# Country : Canada
# Province : Ontario
# City : Toronto

# %%
# Out:
# No of arguments: 3
# Horsefeather
# Adonis
# Bone
# No of arguments: 4
# Sidecar
# Long Island
# Mudslide
# Carriage

# %%
def printDictionary(**args): # passing dictionary thats unlimited in size
    for key in args:
        print(key + " : " + args[key])

printDictionary(Country='Canada',Province='Ontario',City='Toronto')
# Out:
# Country : Canada
# Province : Ontario
# City : Toronto
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       3         print(key + " : " + args[key])
#       5 printDictionary(Country='Canada',Province='Ontario',City='Toronto')
# ----> 6 printDictionary({"Country" :'Canada', "Province" : "Ontario" ,"City": 'Toronto'})
#
# TypeError: printDictionary() takes 0 positional arguments but 1 was given

# %%
def addItems(list): # zmienne przekazane do są "zmienne" za pomocą wskaźnika; na poziomie globalnym
    list.append("Three")
    list.append("Four")

myList = ["One","Two"]

addItems(myList)

myList
# Out:
# ['One', 'Two', 'Three', 'Four']

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01">Joseph Santarcangelo</a>
#
# ## Other contributors
#
# <a href="https://www.linkedin.com/in/jiahui-mavis-zhou-a4537814a?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01">Mavis Zhou</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                                                                                     |
# | ----------------- | ------- | ---------- | ---------------------------------------------------------------------------------------------------------------------- |
# |2022-12-30| 0.5| Pratiksha| Updated exercises|
# | 2022-01-10        | 0.4     | Malika     | Removed the readme for GitShare                                                                                        |
# | 2021-04-13        | 0.3     | Malika     | Deleted exercise "Probability Bag"                                                                                     |
# | 2020-08-26        | 0.2     | Lavanya    | Moved lab to course repo in GitLab                                                                                     |
# | 2020 -09 -04      | 0.2     | Arjun      | Under What is a function, added code/text to further demonstrate the functionality of the return statement             |
# | 2020 -09 -04      | 0.2     | Arjun      | Under Global Variables, modify the code block to try and print ‘internal_var’ - So a nameError message can be observed |
# | 2020 -09 -04      | 0.2     | Arjun      | Added section Collections and Functions                                                                                |
# | 2020 -09 -04      | 0.2     | Arjun      | Added exercise “Probability Bag”                                                                                       |
#
# <hr/>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
